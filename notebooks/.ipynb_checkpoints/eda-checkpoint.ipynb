# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/house_price_dataset_india_12k.csv")

# %%
df.head()
# Out:
#    House_ID       City Locality_Tier  BHK  Bathrooms  Super_Area_sqft  \
# 0         1  Hyderabad           Mid    3          4            957.3
# 1         2  Bangalore        Budget    2          3            883.3
# 2         3       Pune       Premium    3          4           1331.5
# 3         4     Mumbai       Premium    3          4            997.6
# 4         5       Pune           Mid    2          2            967.6
#
#    Carpet_Area_sqft  Floor_No  Total_Floors  Property_Age_years  ...  \
# 0             809.1        11            15                   8  ...
# 1             711.7        13            16                  13  ...
# 2            1087.1        13            15                   7  ...
# 3             801.0         7            19                  10  ...
# 4             707.6         5            16                   6  ...
#
#        Furnishing Lift  Gated_Society  Distance_to_Metro_km  \
# 0  Semi-Furnished    1              0                  2.44
# 1  Semi-Furnished    1              0                  0.48
# 2     Unfurnished    1              1                  2.76
# 3  Semi-Furnished    1              1                  1.12
# 4     Unfurnished    1              1                  2.46
#
#    Distance_to_CityCenter_km  Nearby_School_km  Nearby_Hospital_km  \
# 0                      20.76              1.77                3.52
# 1                      17.56              2.82                4.86
# 2                       9.73              0.20                1.75
# 3                      13.15              0.27                0.61
# 4                      14.07              3.34                3.93
#
#    Crime_Rate_Index  Market_Price_INR  Price_per_sqft_INR
# 0              32.4           7736451                8082
# 1              66.3           5771877                6534
# 2              23.3          14688106               11031
# 3              18.8          19094254               19140
# 4              41.0           7592420                7847
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   House_ID                   12000 non-null  int64
#  1   City                       12000 non-null  object
#  2   Locality_Tier              12000 non-null  object
#  3   BHK                        12000 non-null  int64
#  4   Bathrooms                  12000 non-null  int64
#  5   Super_Area_sqft            12000 non-null  float64
#  6   Carpet_Area_sqft           12000 non-null  float64
#  7   Floor_No                   12000 non-null  int64
#  8   Total_Floors               12000 non-null  int64
#  9   Property_Age_years         12000 non-null  int64
#  10  Parking                    12000 non-null  int64
#  11  Furnishing                 12000 non-null  object
#  12  Lift                       12000 non-null  int64
#  13  Gated_Society              12000 non-null  int64
#  14  Distance_to_Metro_km       12000 non-null  float64
#  15  Distance_to_CityCenter_km  12000 non-null  float64
#  16  Nearby_School_km           12000 non-null  float64
#  17  Nearby_Hospital_km         12000 non-null  float64
#  18  Crime_Rate_Index           12000 non-null  float64
#  19  Market_Price_INR           12000 non-null  int64
#  20  Price_per_sqft_INR         12000 non-null  int64
# dtypes: float64(7), int64(11), object(3)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#           House_ID           BHK     Bathrooms  Super_Area_sqft  \
# count  12000.00000  12000.000000  12000.000000     12000.000000
# mean    6000.50000      2.304167      2.536083      1018.260342
# std     3464.24595      0.934909      1.102482       379.974189
# min        1.00000      1.000000      1.000000       350.000000
# 25%     3000.75000      2.000000      2.000000       781.800000
# 50%     6000.50000      2.000000      2.000000       950.500000
# 75%     9000.25000      3.000000      3.000000      1226.300000
# max    12000.00000      5.000000      7.000000      3010.400000
#
#        Carpet_Area_sqft      Floor_No  Total_Floors  Property_Age_years  \
# count      12000.000000  12000.000000  12000.000000        12000.000000
# mean         763.563383      7.599000     15.232667            8.615917
# std          291.095491      5.685352      5.707604            5.374815
# min          250.000000      0.000000      3.000000            0.000000
# 25%          569.700000      3.000000     11.000000            4.000000
# 50%          715.550000      7.000000     15.000000            8.000000
# 75%          915.200000     11.000000     19.000000           12.000000
# max         2285.900000     32.000000     38.000000           33.000000
#
#             Parking          Lift  Gated_Society  Distance_to_Metro_km  \
# count  12000.000000  12000.000000   12000.000000          12000.000000
# mean       0.640083      0.924167       0.588667              2.153820
# std        0.479996      0.264742       0.492096              1.817501
# min        0.000000      0.000000       0.000000              0.200000
# 25%        0.000000      1.000000       0.000000              0.410000
# 50%        1.000000      1.000000       1.000000              1.830000
# 75%        1.000000      1.000000       1.000000              3.340000
# max        1.000000      1.000000       1.000000             11.600000
#
#        Distance_to_CityCenter_km  Nearby_School_km  Nearby_Hospital_km  \
# count               12000.000000      12000.000000        12000.000000
# mean                   14.101654          2.807817            3.059477
# std                     7.149948          1.352786            1.507851
# min                     0.500000          0.200000            0.300000
# 25%                     9.000000          1.840000            1.990000
# 50%                    14.010000          2.800000            3.000000
# 75%                    19.000000          3.760000            4.080000
# max                    39.800000          8.710000            8.810000
#
#        Crime_Rate_Index  Market_Price_INR  Price_per_sqft_INR
# count      12000.000000      1.200000e+04        12000.000000
# mean          41.756825      1.020406e+07         9689.409667
# std           13.716940      6.707595e+06         4279.861543
# min            5.000000      1.356119e+06         2480.000000
# 25%           32.200000      5.586925e+06         6562.750000
# 50%           41.800000      8.558740e+06         8763.000000
# 75%           51.400000      1.304248e+07        11980.000000
# max           85.400000      5.755283e+07        22626.000000

# %%
df.isnull().sum()
# Out:
# House_ID                     0
# City                         0
# Locality_Tier                0
# BHK                          0
# Bathrooms                    0
# Super_Area_sqft              0
# Carpet_Area_sqft             0
# Floor_No                     0
# Total_Floors                 0
# Property_Age_years           0
# Parking                      0
# Furnishing                   0
# Lift                         0
# Gated_Society                0
# Distance_to_Metro_km         0
# Distance_to_CityCenter_km    0
# Nearby_School_km             0
# Nearby_Hospital_km           0
# Crime_Rate_Index             0
# Market_Price_INR             0
# Price_per_sqft_INR           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['House_ID', 'City', 'Locality_Tier', 'BHK', 'Bathrooms',
#        'Super_Area_sqft', 'Carpet_Area_sqft', 'Floor_No', 'Total_Floors',
#        'Property_Age_years', 'Parking', 'Furnishing', 'Lift', 'Gated_Society',
#        'Distance_to_Metro_km', 'Distance_to_CityCenter_km', 'Nearby_School_km',
#        'Nearby_Hospital_km', 'Crime_Rate_Index', 'Market_Price_INR',
#        'Price_per_sqft_INR'],
#       dtype='object')

# %%
df["BHK"].max()
# Out:
# 5

# %%
df.drop("House_ID", axis=1, inplace=True)

# %%
df.shape
# Out:
# (12000, 20)

# %%
#encoding of categorical data

cat_cols=['City', 'Locality_Tier','Furnishing']

#nemerical columns

num_cols = ["BHK","Bathrooms","Super_Area_sqft","Carpet_Area_sqft","Property_Age_years","Distance_to_Metro_km","Crime_Rate_Index","Price_per_sqft_INR"
]

# %%
#Univariate Analysis
#sns.histplot(df['Market_Price_INR'], kde=True)
df['Market_Price_INR'].dtype
# Out:
# dtype('int64')

# %%
sns.histplot(df['Market_Price_INR'])
plt.show()

# %%
df['Market_Price_INR'].describe()

#convert price into crores
df['Price_Crore'] = df['Market_Price_INR'] / 10000000

# %%
#to know prices of houses
sns.histplot(df['Price_Crore'])   #left skewed
plt.show()

# %%
#type of houses
sns.countplot(x=df['BHK'])
# Out:
# <AxesSubplot:xlabel='BHK', ylabel='count'>

# %%
#city distribution
sns.countplot(x=df['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
sns.countplot(x=df['Furnishing'])
# Out:
# <AxesSubplot:xlabel='Furnishing', ylabel='count'>

# %%
#AREA VS PRICE

sns.scatterplot(
    x=df['Super_Area_sqft'],
    y=df['Market_Price_INR']
)
# Out:
# <AxesSubplot:xlabel='Super_Area_sqft', ylabel='Market_Price_INR'>

# %%
sns.boxplot(
    x=df['BHK'],
    y=df['Market_Price_INR']
)
# Out:
# <AxesSubplot:xlabel='BHK', ylabel='Market_Price_INR'>
